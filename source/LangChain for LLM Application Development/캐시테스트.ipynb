# %%
from langchain_openai import ChatOpenAI

# To control the randomness and creativity of the generated
# text by an LLM, use temperature = 0.0
chat = ChatOpenAI(temperature=0.0, model='gpt-3.5-turbo')

# %%
# from langchain.globals import set_llm_cache
# import redis

# # use any embedding provider...
# from langchain_openai.embeddings.base import OpenAIEmbeddings

redis_url = "redis://192.168.0.4:6379"

from langchain_community.cache import RedisSemanticCache
from langchain_openai import OpenAIEmbeddings

set_llm_cache(
    RedisSemanticCache(redis_url=redis_url, embedding=OpenAIEmbeddings())
)

# %%
chat.invoke('조크 이야기 해줘')
# Out:
# Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.
# Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:276, in Redis.__init__(self, redis_url, index_name, embedding, index_schema, vector_schema, relevance_score_fn, key_prefix, **kwargs)
#     275     # check if redis has redisearch module installed
# --> 276     check_redis_module_exist(redis_client, REDIS_REQUIRED_MODULES)
#     277 except ValueError as e:
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/utilities/redis.py:71, in check_redis_module_exist(client, required_modules)
#      70 logger.error(error_message)
# ---> 71 raise ValueError(error_message)
#
# ValueError: Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/cache.py:654, in RedisSemanticCache._get_llm_cache(self, llm_string)
#     653 try:
# --> 654     self._cache_dict[index_name] = RedisVectorstore.from_existing_index(
#     655         embedding=self.embedding,
#     656         index_name=index_name,
#     657         redis_url=self.redis_url,
#     658         schema=cast(Dict, self.DEFAULT_SCHEMA),
#     659     )
#     660 except ValueError:
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:556, in Redis.from_existing_index(cls, embedding, index_name, schema, key_prefix, **kwargs)
#     554 # Create instance
#     555 # init the class -- if Redis is unavailable, will throw exception
# --> 556 instance = cls(
#     557     redis_url,
#     558     index_name,
#     559     embedding,
#     560     index_schema=schema,
#     561     key_prefix=key_prefix,
#     562     **kwargs,
#     563 )
#     565 # Check for existence of the declared index
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:278, in Redis.__init__(self, redis_url, index_name, embedding, index_schema, vector_schema, relevance_score_fn, key_prefix, **kwargs)
#     277 except ValueError as e:
# --> 278     raise ValueError(f"Redis failed to connect: {e}")
#     280 self.client = redis_client
#
# ValueError: Redis failed to connect: Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:276, in Redis.__init__(self, redis_url, index_name, embedding, index_schema, vector_schema, relevance_score_fn, key_prefix, **kwargs)
#     275     # check if redis has redisearch module installed
# --> 276     check_redis_module_exist(redis_client, REDIS_REQUIRED_MODULES)
#     277 except ValueError as e:
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/utilities/redis.py:71, in check_redis_module_exist(client, required_modules)
#      70 logger.error(error_message)
# ---> 71 raise ValueError(error_message)
#
# ValueError: Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 chat.invoke('조크 이야기 해줘')
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:170, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     159 def invoke(
#     160     self,
#     161     input: LanguageModelInput,
#    (...)
#     165     **kwargs: Any,
#     166 ) -> BaseMessage:
#     167     config = ensure_config(config)
#     168     return cast(
#     169         ChatGeneration,
# --> 170         self.generate_prompt(
#     171             [self._convert_input(input)],
#     172             stop=stop,
#     173             callbacks=config.get("callbacks"),
#     174             tags=config.get("tags"),
#     175             metadata=config.get("metadata"),
#     176             run_name=config.get("run_name"),
#     177             run_id=config.pop("run_id", None),
#     178             **kwargs,
#     179         ).generations[0][0],
#     180     ).message
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:632, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     630 llm_string = self._get_llm_string(stop=stop, **kwargs)
#     631 prompt = dumps(messages)
# --> 632 cache_val = llm_cache.lookup(prompt, llm_string)
#     633 if isinstance(cache_val, list):
#     634     return ChatResult(generations=cache_val)
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/cache.py:684, in RedisSemanticCache.lookup(self, prompt, llm_string)
#     682 def lookup(self, prompt: str, llm_string: str) -> Optional[RETURN_VAL_TYPE]:
#     683     """Look up based on prompt and llm_string."""
# --> 684     llm_cache = self._get_llm_cache(llm_string)
#     685     generations: List = []
#     686     # Read from a Hash
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/cache.py:661, in RedisSemanticCache._get_llm_cache(self, llm_string)
#     654     self._cache_dict[index_name] = RedisVectorstore.from_existing_index(
#     655         embedding=self.embedding,
#     656         index_name=index_name,
#     657         redis_url=self.redis_url,
#     658         schema=cast(Dict, self.DEFAULT_SCHEMA),
#     659     )
#     660 except ValueError:
# --> 661     redis = RedisVectorstore(
#     662         embedding=self.embedding,
#     663         index_name=index_name,
#     664         redis_url=self.redis_url,
#     665         index_schema=cast(Dict, self.DEFAULT_SCHEMA),
#     666     )
#     667     _embedding = self.embedding.embed_query(text="test")
#     668     redis._create_index_if_not_exist(dim=len(_embedding))
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:278, in Redis.__init__(self, redis_url, index_name, embedding, index_schema, vector_schema, relevance_score_fn, key_prefix, **kwargs)
#     276     check_redis_module_exist(redis_client, REDIS_REQUIRED_MODULES)
#     277 except ValueError as e:
# --> 278     raise ValueError(f"Redis failed to connect: {e}")
#     280 self.client = redis_client
#     281 self.relevance_score_fn = relevance_score_fn
#
# ValueError: Redis failed to connect: Redis cannot be used as a vector database without RediSearch >=2.4Please head to https://redis.io/docs/stack/search/quick_start/to know more about installing the RediSearch module within Redis Stack.

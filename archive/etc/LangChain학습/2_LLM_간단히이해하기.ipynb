# %% [markdown]
# ## LLM의 구조
# - 최근의  NLP모델의 대부분은 Transfomer아키텍처를 기반으로 하며 모델의 용도에 따라 Encoder, decoder 구조를가지고 있음
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
